# %%
import numpy as np
import pandas as pd
import csv
import math
csv_reader=pd.read_csv(open('data/train.csv'))

# %%
print(csv_reader.head(1))
# Out:
#    id   var1    var2  var3  var4  var5  var6  var7  var8  var9  ...    var524  \
# 0   0  916.0  5000.0     6     1     2  60.0     0     0     1  ...       NaN
#
#    var525  var526  var527  var528  var529  var530  var531  var532 target
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN      0
#
# [1 rows x 534 columns]

# %%
arr=np.array(csv_reader)

# %%
arra=np.zeros(shape=(24309,517),dtype=np.float32)

# %%
n=0
for i in range(533):
    if(i==3 or i==11 or i>=16 and i<=25 or i==45 or i>=124 and i<=126):
        aaa=1
    else:
        arra[:,n]=arr[:,i]
        n+=1
print(arra[0])
# Out:
# [  0.00000000e+00   9.16000000e+02   5.00000000e+03   1.00000000e+00
#    2.00000000e+00   6.00000000e+01   0.00000000e+00   0.00000000e+00
#    1.00000000e+00   4.40000000e+01   3.20000000e+01   1.00000000e+00
#    9.16000000e+02   1.00000000e+00   4.60000000e+01   5.09999990e-01
#    2.56000000e+02   1.23000000e+02   1.33000000e+02   2.55000000e+02
#               nan   1.00000000e+00              nan   0.00000000e+00
#    4.09999996e-01   1.29500000e+03   1.08000000e+02   8.00000000e+01
#    1.33000000e+02   1.08000000e+02              nan   2.80000000e+01
#               nan   1.00000000e+00   0.00000000e+00   3.60000000e+01
#    1.75699997e+01   1.90000000e+01   3.64300003e+01              nan
#    1.40000001e-01   6.20000000e+01   6.00000000e+00   3.40000000e+01
#    3.70000000e+01              nan   3.95600000e+03   1.41014001e+03
#    2.54586011e+03   3.95200000e+03              nan   4.00000000e+00
#    1.22000000e+02   8.06803284e+01   1.74300003e+01   1.40614001e+03
# ...

# %%
print(arra[:,0])
np.savetxt("data/number.txt",arra)
# Out:
# [  0.00000000e+00   1.00000000e+00   2.00000000e+00 ...,   2.43060000e+04
#    2.43070000e+04   2.43080000e+04]

# %%
a=np.loadtxt('data/number.txt')
print(a.shape)
# Out:
# (24309, 517)

# %%
print(arr[:,533])
# Out:
# [0 0 1 ..., 0 0 0]

# %%
np.savetxt('data/labels',arr[:,533])

# %%
aaaa=np.loadtxt('data/labels')
aaaa.shape=(24309,1)
print(aaaa.shape)
# Out:
# (24309, 1)

# %%
type=np.zeros(shape=(24309,16))

# %%
city1=['北京','上海','深圳','天津','广州']
file=open('data/city1.txt','w')
file.write(str(city1))
file.close()

# %%
file=open('data/city1.txt','r')
ci=file.readline()
print(ci.)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-294dc08bc6f6> in <module>()
#       1 file=open('data/city1.txt','r')
#       2 ci=file.readline()
# ----> 3 print(ci.shape)
#
# AttributeError: 'str' object has no attribute 'shape'
